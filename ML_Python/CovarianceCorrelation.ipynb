# %%
import numpy as np
import matplotlib.pyplot as plt


def de_mean(x):
    xmean = mean(x)
    return ([xi-xmean for xi in x])

def covariance (x, y):
    n= len(x)
    return (dot(de_mean(x), de_mean(y)) / (n-1))

pageSpeeds = np.random.normal(3.0, 1.0, 1000)
purchaseAmount = np.random.normal (50.0, 10.0, 1000)

plt.scatter(pageSpeeds, purchaseAmount)

# covariance (pageSpeeds, purchaseAmout)
np.cov(pageSpeeds, purchaseAmount)
plt.show()

# %%
purchaseAmount = np.random.normal(50.0, 10.0, 1000) / pageSpeeds

plt.scatter(pageSpeeds, purchaseAmount )

# covariance (pageSpeeds, purchaseAmount)

np.cov(pageSpeeds, purchaseAmount)
plt.show()

# %%
def correlation(x, y):
    stddevx = x.std()
    stddevy = y.std()
    return np.cov(x,y) / stddevx /stddevy



print (correlation(pageSpeeds, purchaseAmount))
# Out:
# [[  4.71643378e-03   1.05851700e-01]
#  [  1.05851700e-01   2.12449289e+02]]

# %%
np.cov(pageSpeeds, purchaseAmount)
# Out:
# array([[  1.02168710e+00,   2.29298920e+01],
#        [  2.29298920e+01,   4.60213603e+04]])

# %%
np.corrcoef(pageSpeeds, purchaseAmount)
# Out:
# array([[ 1.        ,  0.10574585],
#        [ 0.10574585,  1.        ]])

# %%
purchaseAmount =100-pageSpeeds*3

plt.scatter(pageSpeeds, perchaseAmount)
np

# %%
import numpy as np
import matplotlib.pyplot as plt


N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2  # 0 to 15 point radiuses

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()
